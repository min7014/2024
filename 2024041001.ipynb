# %% [markdown]
# <a href="https://colab.research.google.com/github/min7014/2024/blob/main/2024041001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 매개변수로 나타낸 곡선의 접선(Tangent to a Parametric Curve)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # < Geogebra >

# %% [markdown]
# - https://www.geogebra.org
#
#
# - **Geogebra 5 설치 링크(installation link)(windows)**
#  - [Reference:GeoGebra Installation](https://wiki.geogebra.org/en/Reference:GeoGebra_Installation)
#    - [Windows Installer: GeoGebra Classic 5 Installer for Windows](https://download.geogebra.org/package/win)
#
#    - [Windows Portable: GeoGebra Classic 5 Portable for Windows](https://download.geogebra.org/package/win-port)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Geogebra 영어판으로 강의록 만들었습니다. Geogebra가 한글판으로 되어있어도 영문으로 바꿀 수 있습니다. [선택사항], [언어], [E-I], [English(US)] 를 차례로 선택하여 언어를 변경하시면 됩니다.

# %% [markdown]
# I created a lecture transcript using the English version of Geogebra. Even if Geogebra is in Korean, you can change it to English. You can change the language by selecting [선택사항], [언어], [E-I], [English(US)] in that order.

# %% [markdown]
# # 시작(Start)

# %% [markdown]
# 01. Geogebra를 실행시킨다.
#
#   Run Geogebra.

# %% [markdown]
# 02. [Algebra]창에  오른쪽 방향 선택하면 아래방향으로 바뀌면서 추가메뉴가 나오면 첫 번째 아래방향을 선택하여 [Sort by:]에서 [Construction Order]를 선택한다.
#
#   When you select the right direction in the [Algebra] window, it changes to the downward direction and an additional menu appears. Select the first downward direction and select [Construction Order] from [Sort by:].

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 03. [Input]창에 f(t)=cos(t)^3 을 입력하여 함수 $f$를 만든다.
#
#   Create function $f$ by entering f(t)=cos(t)^3 in the [Input] window.

# %% [markdown]
# 04. [Input]창에 SetVisibleInView[f,1,false] 을 입력하여 함수 f를 기하창에서 보이지 않게 한다.
#
#   Enter SetVisibleInView[f,1,false] in the [Input] window to make function f invisible in the geometry window.

# %% [markdown]
# 05. [Input]창에 g(t)=sin(t)^3 을 입력하여 함수 $g$를 만든다.
#
#   Create function $g$ by entering g(t)=sin(t)^3 in the [Input] window.

# %% [markdown]
# 06. [Input]창에 SetVisibleInView[g,1,false] 을 입력하여 함수 f를 기하창에서 보이지 않게 한다.
#
#   Enter SetVisibleInView[g,1,false] in the [Input] window to make function f invisible in the geometry window.

# %% [markdown]
# 07. [Input]창에 a=0 를 입력하여 수 a를 만든다.
#
#   Enter a=0 in the [Input] window to create the number a.

# %% [markdown]
# 08. [Input]창에 b=2pi 를 입력하여 수 b를 만든다.
#
#   Enter b=2pi in the [Input] window to create the number b.

# %% [markdown]
# 09. [Input]창에 t=Slider[a,b] 를 입력하여 수 t를 만든다.
#
#   Enter t=Slider[a,b] in the [Input] window to create the number t.

# %% [markdown]
# 10. [Input]창에  P=(f(t),g(t)) 를 입력하여 수 t의 값에 따라 x좌표는 f(t) y좌표는 g(t)인 점 P를 만든다.
#
#   Enter P=(f(t),g(t)) in the [Input] window to create a point P whose x-coordinate is f(t) and y-coordinate is g(t) depending on the value of number t.

# %% [markdown]
# 11. [Input]창에 t=0.5 를 입력하여 수 t를 0.5로 만든다.
#
#   Enter t=0.5 in the [Input] window to set the number t to 0.5.

# %% [markdown]
# 12. [Inpute]창에 SetCaption(P,"\$\mathrm{P}\$") 를 입력하여 점 P를 이름을 Latex 수식으로 이쁘게 만든다.
#
#   Enter SetCaption(P,"\$\mathrm{P}\$") in the [Inpute] window to give point P a nice name with a Latex formula.

# %% [markdown]
# 13. [Input]창에 SetColor[P,"Red"]를 입력하여 점 P의 색상을 빨강으로 한다.
#
#   Enter SetColor[P,"Red"] in the [Input] window to set the color of point P to red.

# %% [markdown]
# 14. [Input]창에 c=Curve[f(v),g(v),v,a,b]를 입력하여 매개변수 곡선 c를 만든다.
#
#   Enter c=Curve[f(v),g(v),v,a,b] in the [Input] window to create a parametric curve c.

# %% [markdown]
# 15.  [Input]창에 SetColor[c,"Blue"]를 입력하여 매개변수 곡선 c의 색상을 파랑으로 한다.
#
#   Enter SetColor[c,"Blue"] in the [Input] window to set the color of the parameter curve c to blue.

# %% [markdown]
# 16. [Algebra]창과 [Graphics]창 경계에 마우스를 위치시켰을때 마우스 커서가 좌우화살표로 변한다. 이때 왼쪽 마우스를 누른 상태로 대수창을 넓혀서 곡선 c의 내용이 다 보이도록 창의 너비를 조절한다.
#
#   When you place the mouse on the border of the [Algebra] window and the [Graphics] window, the mouse cursor changes to a left or right arrow. At this time, expand the algebra window while pressing the left mouse button and adjust the width of the window so that the contents of curve c are fully visible.

# %% [markdown]
# 17. [Input]에 m=Tangent[P,c] 를 입력하여 매개변수 곡선 c의 점 P에서의 접선 m을 만든다.
#
#   Enter m=Tangent[P,c] in [Input] to create a tangent m at point P of the parametric curve c.

# %% [markdown]
# 18.  [Input]창에 SetColor[m,"Red"]를 입력하여 점 P의 색상을 빨강으로 한다.
#
#   Enter SetColor[m,"Red"] in the [Input] window to set the color of point P to red.

# %% [markdown]
# 19. [Algebra]창의 t를 선택하거나 [Graphics]창의 슬라이더 t 를 선택하고 좌 우 방향키를 눌러보면 수 t의 값에 따라 매개변수 곡선에 접선 m이 그려진다.
#
#   If you select t in the [Algebra] window or select the slider t in the [Graphics] window and press the left or right arrow keys, a tangent line m will be drawn on the parameter curve according to the value of the number t.

# %% [markdown]
# 20. [Input]창에 StartAnimation[t, true] 를 입력하여 수 t의 값이 자동으로 변하게 한다. 또한 입력창에 StartAnimation[t,false] 를 입력하여 수 t의 값이 변하는 것을 멈출 수 있다.
#
#   Enter StartAnimation[t, true] in the [Input] window to automatically change the value of the number t. You can also stop the value of the number t from changing by entering StartAnimation[t,false] in the input window.

# %% [markdown]
# ex)
#
# - f(t)=3cos[t]
#
#   g(t)=3sin[t]
#
#   a=0
#
#   b=2pi
#
#
#
# - f(t)=cos[2t]
#
#   g(t)=2cos[t]
#
#   a=0
#
#   b=pi
#
#
#
# - f(t)=sin[t]
#
#   g(t)=cos[2t]
#
#   a=pi/2
#
#   b=3pi/2
#
#
#
# - f(t)=t-sin[t]
#
#   g(t)=1-cos[t]
#
#   a=0
#
#   b=2pi
