# %% [markdown]
# <a href="https://colab.research.google.com/github/min7014/2024/blob/main/2024071601.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 이변량 회귀분석(Two Variable Regression Analysis)

# %% [markdown]
# ## Geogebra 영문버전 설치(Install Geogebra English version)

# %% [markdown]
# [Geogebra 영문버전 설치(Install Geogebra English version)](https://colab.research.google.com/github/min7014/2024/blob/main/2024042001.ipynb)

# %% [markdown]
# 아래 강의록을 시작하기 전에 우선 위 링크를 클릭하여 Geogebra 영문버전을 설치하시기 바랍니다.

# %% [markdown]
# Before starting the lecture notes below, please click the link above to install the English version of Geogebra.

# %% [markdown]
# # 강의록 시작(Start lecture notes)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Geogebra에 [View]를 선택하시고 [Spreadsheet]를 선택합니다. [Spreadsheet] 창이 나타나는 것을 보실 수 있습니다.

# %% [markdown]
# Select [View] in Geogebra and select [Spreadsheet]. You can see the [Spreadsheet] window appear.

# %% [markdown]
# - [별 관측 데이타(Star observation data)](https://min7014.github.io/2021/2021042619.xls)

# %% [markdown]
# [Excel]의 자료는 과학고에서 별 관측하면서 얻은 별의 시간과 위치에 관한 자료입니다. 다른 수치 자료를 사용하셔도 됩니다.

# %% [markdown]
# The data in [Excel] is about the time and position of stars obtained while observing stars at a science high school. You can use other numerical data.

# %% [markdown]
# 엑셀자료를 스프레드시트 창에 복사 해놓습니다. 그리고 선택을 하시고 이변량 회귀분석 도구를 선택합니다. 자료분석 화면에 회귀모델을 자료에 맞게 선택하시면 회귀모델 식이 자동으로 생성되는 것을 보실 수 있습니다. 아마도 자료를 분석하는 과학 분야에서 유용하게 쓸 수 있는 기능일 것입니다.
